# %% [markdown]
# <a href="https://colab.research.google.com/github/teng-joyeen/teng-joyeen.github.io/blob/master/TRAIN2_Multi_Class_Weather_Recognition_and_Classification_On_Outdoor_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import zipfile

local_zip = '/content/drive/My Drive/weather_classification.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/My Drive/weather_classification')
zip_ref.close()

# !rm -rf weather_classification.zip

# %%
import os, shutil

cloudy_dataset_dir = '/My Drive/weather_classification/cloudy'
rainy_dataset_dir = '/My Drive/weather_classification/rainy'
sunny_dataset_dir = '/My Drive/weather_classification/sunny'
snowy_dataset_dir = '/My Drive/weather_classification/snowy'

base_dir = '/My Drive/weather'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)

train_cloudy_dir = os.path.join(train_dir, 'cloudy')
os.mkdir(train_cloudy_dir)
train_rainy_dir = os.path.join(train_dir, 'rainy')
os.mkdir(train_rainy_dir)
train_sunny_dir = os.path.join(train_dir, 'sunny')
os.mkdir(train_sunny_dir)
train_snowy_dir = os.path.join(train_dir, 'snowy')
os.mkdir(train_snowy_dir)

validation_cloudy_dir = os.path.join(validation_dir, 'cloudy')
os.mkdir(validation_cloudy_dir)
validation_rainy_dir = os.path.join(validation_dir, 'rainy')
os.mkdir(validation_rainy_dir)
validation_sunny_dir = os.path.join(validation_dir, 'sunny')
os.mkdir(validation_sunny_dir)
validation_snowy_dir = os.path.join(validation_dir, 'snowy')
os.mkdir(validation_snowy_dir)

test_cloudy_dir = os.path.join(test_dir, 'cloudy')
os.mkdir(test_cloudy_dir)
test_rainy_dir = os.path.join(test_dir, 'rainy')
os.mkdir(test_rainy_dir)
test_sunny_dir = os.path.join(test_dir, 'sunny')
os.mkdir(test_sunny_dir)
test_snowy_dir = os.path.join(test_dir, 'snowy')
os.mkdir(test_snowy_dir)

# %%
fnames = ['cloudy_0000{}.jpg'.format(i) for i in range(0, 10)]
for fname in fnames:
  src = os.path.join(cloudy_dataset_dir, fname)
  dst = os.path.join(train_cloudy_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['cloudy_000{}.jpg'.format(i) for i in range(10, 100)]
for fname in fnames:
  src = os.path.join(cloudy_dataset_dir, fname)
  dst = os.path.join(train_cloudy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['cloudy_00{}.jpg'.format(i) for i in range(100, 1000)]
for fname in fnames:
  src = os.path.join(cloudy_dataset_dir, fname)
  dst = os.path.join(train_cloudy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['cloudy_0{}.jpg'.format(i) for i in range(1000, 6000)]
for fname in fnames:
  src = os.path.join(cloudy_dataset_dir, fname)
  dst = os.path.join(train_cloudy_dir, fname)
  shutil.copyfile(src, dst)  
  
fnames = ['cloudy_0{}.jpg'.format(i) for i in range(6000, 8000)]
for fname in fnames:
  src = os.path.join(cloudy_dataset_dir, fname)
  dst = os.path.join(validation_cloudy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['cloudy_0{}.jpg'.format(i) for i in range(8000, 10000)]
for fname in fnames:
  src = os.path.join(cloudy_dataset_dir, fname)
  dst = os.path.join(test_cloudy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['rainy_0000{}.jpg'.format(i) for i in range(0, 10)]
for fname in fnames:
  src = os.path.join(rainy_dataset_dir, fname)
  dst = os.path.join(train_rainy_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['rainy_000{}.jpg'.format(i) for i in range(10, 100)]
for fname in fnames:
  src = os.path.join(rainy_dataset_dir, fname)
  dst = os.path.join(train_rainy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['rainy_00{}.jpg'.format(i) for i in range(100, 1000)]
for fname in fnames:
  src = os.path.join(rainy_dataset_dir, fname)
  dst = os.path.join(train_rainy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['rainy_0{}.jpg'.format(i) for i in range(1000, 6000)]
for fname in fnames:
  src = os.path.join(rainy_dataset_dir, fname)
  dst = os.path.join(train_rainy_dir, fname)
  shutil.copyfile(src, dst)  
  
fnames = ['rainy_0{}.jpg'.format(i) for i in range(6000, 8000)]
for fname in fnames:
  src = os.path.join(rainy_dataset_dir, fname)
  dst = os.path.join(validation_rainy_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['rainy_0{}.jpg'.format(i) for i in range(8000, 10000)]
for fname in fnames:
  src = os.path.join(rainy_dataset_dir, fname)
  dst = os.path.join(test_rainy_dir, fname)
  shutil.copyfile(src, dst) 

fnames = ['sunny_0000{}.jpg'.format(i) for i in range(0, 10)]
for fname in fnames:
  src = os.path.join(sunny_dataset_dir, fname)
  dst = os.path.join(train_sunny_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['sunny_000{}.jpg'.format(i) for i in range(10, 100)]
for fname in fnames:
  src = os.path.join(sunny_dataset_dir, fname)
  dst = os.path.join(train_sunny_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['sunny_00{}.jpg'.format(i) for i in range(100, 1000)]
for fname in fnames:
  src = os.path.join(sunny_dataset_dir, fname)
  dst = os.path.join(train_sunny_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['sunny_0{}.jpg'.format(i) for i in range(1000, 6000)]
for fname in fnames:
  src = os.path.join(sunny_dataset_dir, fname)
  dst = os.path.join(train_sunny_dir, fname)
  shutil.copyfile(src, dst)  
  
fnames = ['sunny_0{}.jpg'.format(i) for i in range(6000, 8000)]
for fname in fnames:
  src = os.path.join(sunny_dataset_dir, fname)
  dst = os.path.join(validation_sunny_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['sunny_0{}.jpg'.format(i) for i in range(8000, 10000)]
for fname in fnames:
  src = os.path.join(sunny_dataset_dir, fname)
  dst = os.path.join(test_sunny_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['snow_0000{}.jpg'.format(i) for i in range(0, 10)]
for fname in fnames:
  src = os.path.join(snowy_dataset_dir, fname)
  dst = os.path.join(train_snowy_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['snow_000{}.jpg'.format(i) for i in range(10, 100)]
for fname in fnames:
  src = os.path.join(snowy_dataset_dir, fname)
  dst = os.path.join(train_snowy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['snow_00{}.jpg'.format(i) for i in range(100, 1000)]
for fname in fnames:
  src = os.path.join(snowy_dataset_dir, fname)
  dst = os.path.join(train_snowy_dir, fname)
  shutil.copyfile(src, dst)
  
fnames = ['snow_0{}.jpg'.format(i) for i in range(1000, 6000)]
for fname in fnames:
  src = os.path.join(snowy_dataset_dir, fname)
  dst = os.path.join(train_snowy_dir, fname)
  shutil.copyfile(src, dst)  
  
fnames = ['snow_0{}.jpg'.format(i) for i in range(6000, 8000)]
for fname in fnames:
  src = os.path.join(snowy_dataset_dir, fname)
  dst = os.path.join(validation_snowy_dir, fname)
  shutil.copyfile(src, dst)

fnames = ['snow_0{}.jpg'.format(i) for i in range(8000, 10000)]
for fname in fnames:
  src = os.path.join(snowy_dataset_dir, fname)
  dst = os.path.join(test_snowy_dir, fname)
  shutil.copyfile(src, dst)
  
print('total training cloudy images:', len(os.listdir(train_cloudy_dir)))
print('total training rainy images:', len(os.listdir(train_rainy_dir)))
print('total training sunny images:', len(os.listdir(train_sunny_dir)))
print('total training snowy images:', len(os.listdir(train_snowy_dir)))
  
print('total validation cloudy images:', len(os.listdir(validation_cloudy_dir)))
print('total validation rainy images:', len(os.listdir(validation_rainy_dir)))
print('total validation sunny images:', len(os.listdir(validation_sunny_dir)))
print('total validation snowy images:', len(os.listdir(validation_snowy_dir)))

print('total test cloudy images:', len(os.listdir(test_cloudy_dir)))
print('total test rainy images:', len(os.listdir(test_rainy_dir)))
print('total test sunny images:', len(os.listdir(test_sunny_dir)))
print('total test snowy images:', len(os.listdir(test_snowy_dir)))
# Out:
# total training cloudy images: 6000
# total training rainy images: 6000
# total training sunny images: 6000
# total training snowy images: 6000
# total validation cloudy images: 2000
# total validation rainy images: 2000
# total validation sunny images: 2000
# total validation snowy images: 2000
# total test cloudy images: 2000
# total test rainy images: 2000
# total test sunny images: 2000
# total test snowy images: 2000

# %% [markdown]
# Model 1 - 16 32 / 256 / 0.001

# %%
# Model 1
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               10617088
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 10,623,204
# Trainable params: 10,623,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 113s - loss: 2.4005 - acc: 0.5349 - val_loss: 0.9966 - val_acc: 0.6009
# Epoch 2/10
#  - 110s - loss: 0.8163 - acc: 0.6716 - val_loss: 0.8140 - val_acc: 0.6776
# Epoch 3/10
#  - 108s - loss: 0.6437 - acc: 0.7503 - val_loss: 0.9023 - val_acc: 0.6498
# Epoch 4/10
#  - 107s - loss: 0.4534 - acc: 0.8297 - val_loss: 0.9520 - val_acc: 0.6565
# Epoch 5/10
#  - 107s - loss: 0.3069 - acc: 0.8905 - val_loss: 1.1574 - val_acc: 0.6551
# Epoch 6/10
#  - 107s - loss: 0.2102 - acc: 0.9287 - val_loss: 1.4666 - val_acc: 0.6248
# Epoch 7/10
#  - 108s - loss: 0.1615 - acc: 0.9487 - val_loss: 1.8084 - val_acc: 0.6322
# Epoch 8/10
#  - 109s - loss: 0.1334 - acc: 0.9614 - val_loss: 1.8986 - val_acc: 0.6480
# Epoch 9/10
#  - 111s - loss: 0.1171 - acc: 0.9662 - val_loss: 1.9175 - val_acc: 0.6339
# Epoch 10/10
#  - 113s - loss: 0.0992 - acc: 0.9730 - val_loss: 1.9750 - val_acc: 0.6464

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.990625
# train_loss: 0.04617862893268466
# validation_acc: 0.635625
# validation_loss: 1.9422431194782257

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model1.h5')

# %%
img_path = '/My Drive/weather/test/snowy/snow_08500.jpg'

from keras.preprocessing import image
import numpy as np

img = image.load_img(img_path, target_size=(150, 150))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

import matplotlib.pyplot as plt

plt.imshow(img_tensor[0])
plt.show()

from keras import models

layer_outputs = [layer.output for layer in model.layers[:4]]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_tensor)

first_layer_activation = activations[0]
print(first_layer_activation.shape)
# Out:
# (1, 148, 148, 16)

# %%
layer_names = []
for layer in model.layers[:4]:
  layer_names.append(layer.name)
  
images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activations):
  n_features = layer_activation.shape[-1]
  
  size = layer_activation.shape[1]   
  
  n_cols = n_features // images_per_row
  display_grid = np.zeros((size * n_cols, images_per_row * size))
  
  for col in range(n_cols):     
    for row in range(images_per_row):
      channel_image = layer_activation[0, 
                                       :, :, 
                                       col * images_per_row + row]
      channel_image -= channel_image.mean()
      channel_image /= channel_image.std()
      channel_image *= 64
      channel_image += 128
      channel_image = np.clip(channel_image, 0, 255).astype('uint8')    
      display_grid[col * size : (col + 1) * size,
                   row * size : (row + 1) * size] = channel_image
  
  scale = 1. / size
  plt.figure(figsize=(scale * display_grid.shape[1],
                      scale * display_grid.shape[0]))
  plt.title(layer_name)
  plt.grid(False)
  plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# Model 2 - 16 32 64 / 256 Dropout / 0.001
# Add convolution layer with 64 filters and dropout

# %%
# Model 2
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               4735232
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 4,759,844
# Trainable params: 4,759,844
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 113s - loss: 1.0423 - acc: 0.5651 - val_loss: 0.9206 - val_acc: 0.6162
# Epoch 2/10
#  - 109s - loss: 0.8716 - acc: 0.6493 - val_loss: 0.7950 - val_acc: 0.6804
# Epoch 3/10
#  - 108s - loss: 0.8008 - acc: 0.6813 - val_loss: 1.1100 - val_acc: 0.6191
# Epoch 4/10
#  - 107s - loss: 0.7644 - acc: 0.6998 - val_loss: 0.7367 - val_acc: 0.7009
# Epoch 5/10
#  - 106s - loss: 0.7388 - acc: 0.7115 - val_loss: 0.7797 - val_acc: 0.6934
# Epoch 6/10
#  - 106s - loss: 0.7168 - acc: 0.7225 - val_loss: 0.7920 - val_acc: 0.6873
# Epoch 7/10
#  - 106s - loss: 0.7113 - acc: 0.7223 - val_loss: 0.8380 - val_acc: 0.6887
# Epoch 8/10
#  - 105s - loss: 0.7111 - acc: 0.7295 - val_loss: 0.8470 - val_acc: 0.6783
# Epoch 9/10
#  - 105s - loss: 0.6985 - acc: 0.7347 - val_loss: 0.7793 - val_acc: 0.6969
# Epoch 10/10
#  - 105s - loss: 0.7259 - acc: 0.7270 - val_loss: 0.7578 - val_acc: 0.7083

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.8025
# train_loss: 0.5774710935354233
# validation_acc: 0.714375
# validation_loss: 0.733678389787674

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model2.h5')

# %% [markdown]
# Model 3 - 16 32 64 128 / 128 Dropout / 0.001
# Add convolution layer with 128 filters  and reduce number of neurons to 128 of fully connected layer

# %%
# Model 3
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               802944
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 900,900
# Trainable params: 900,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 107s - loss: 1.0545 - acc: 0.5509 - val_loss: 0.8984 - val_acc: 0.6426
# Epoch 2/10
#  - 105s - loss: 0.8921 - acc: 0.6402 - val_loss: 1.0159 - val_acc: 0.5734
# Epoch 3/10
#  - 105s - loss: 0.8417 - acc: 0.6654 - val_loss: 0.7839 - val_acc: 0.6791
# Epoch 4/10
#  - 105s - loss: 0.8122 - acc: 0.6762 - val_loss: 0.7834 - val_acc: 0.6786
# Epoch 5/10
#  - 105s - loss: 0.7921 - acc: 0.6884 - val_loss: 0.8477 - val_acc: 0.6761
# Epoch 6/10
#  - 105s - loss: 0.7811 - acc: 0.6950 - val_loss: 0.8488 - val_acc: 0.6606
# Epoch 7/10
#  - 105s - loss: 0.7813 - acc: 0.6923 - val_loss: 0.7665 - val_acc: 0.6997
# Epoch 8/10
#  - 105s - loss: 0.7851 - acc: 0.6946 - val_loss: 0.7417 - val_acc: 0.6951
# Epoch 9/10
#  - 105s - loss: 0.7838 - acc: 0.6900 - val_loss: 0.8161 - val_acc: 0.6709
# Epoch 10/10
#  - 106s - loss: 0.7875 - acc: 0.6928 - val_loss: 0.7999 - val_acc: 0.6783

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.70375
# train_loss: 0.7404729819297791
# validation_acc: 0.674375
# validation_loss: 0.8076535129547119

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model3.h5')

# %% [markdown]
# Model 4 - 16 32 64 128 / 128 Dropout 128 Dropout / 0.0001
# Lower the learning rate to 0.0001 and add fully connected layer

# %%
# Model 4
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               802944
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 917,412
# Trainable params: 917,412
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 108s - loss: 1.2148 - acc: 0.4407 - val_loss: 0.9953 - val_acc: 0.5855
# Epoch 2/10
#  - 105s - loss: 1.0332 - acc: 0.5643 - val_loss: 0.9217 - val_acc: 0.6132
# Epoch 3/10
#  - 105s - loss: 0.9584 - acc: 0.6044 - val_loss: 0.8897 - val_acc: 0.6326
# Epoch 4/10
#  - 105s - loss: 0.9140 - acc: 0.6268 - val_loss: 0.8372 - val_acc: 0.6548
# Epoch 5/10
#  - 105s - loss: 0.8793 - acc: 0.6468 - val_loss: 0.8246 - val_acc: 0.6633
# Epoch 6/10
#  - 105s - loss: 0.8561 - acc: 0.6580 - val_loss: 0.7956 - val_acc: 0.6725
# Epoch 7/10
#  - 105s - loss: 0.8295 - acc: 0.6707 - val_loss: 0.8081 - val_acc: 0.6677
# Epoch 8/10
#  - 105s - loss: 0.8101 - acc: 0.6783 - val_loss: 0.7757 - val_acc: 0.6857
# Epoch 9/10
#  - 105s - loss: 0.7865 - acc: 0.6912 - val_loss: 0.7784 - val_acc: 0.6813
# Epoch 10/10
#  - 105s - loss: 0.7684 - acc: 0.6983 - val_loss: 0.7333 - val_acc: 0.7025

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.738125
# train_loss: 0.6652452218532562
# validation_acc: 0.696875
# validation_loss: 0.7613095557689666

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model4.h5')

# %% [markdown]
# Model 5 - 16 32 64 128 / 128 Dropout 128 Dropout / 0.0001 / 64
# Increase batch size

# %%
# Model 5
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               802944
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 917,412
# Trainable params: 917,412
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=64,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=64,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=375,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=125,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 106s - loss: 1.2254 - acc: 0.4335 - val_loss: 1.0331 - val_acc: 0.5674
# Epoch 2/10
#  - 103s - loss: 1.0589 - acc: 0.5476 - val_loss: 0.9660 - val_acc: 0.5849
# Epoch 3/10
#  - 104s - loss: 0.9899 - acc: 0.5832 - val_loss: 0.9207 - val_acc: 0.6164
# Epoch 4/10
#  - 104s - loss: 0.9518 - acc: 0.6087 - val_loss: 0.8778 - val_acc: 0.6358
# Epoch 5/10
#  - 106s - loss: 0.9209 - acc: 0.6228 - val_loss: 0.8687 - val_acc: 0.6392
# Epoch 6/10
#  - 108s - loss: 0.8947 - acc: 0.6363 - val_loss: 0.8688 - val_acc: 0.6350
# Epoch 7/10
#  - 107s - loss: 0.8740 - acc: 0.6486 - val_loss: 0.8587 - val_acc: 0.6472
# Epoch 8/10
#  - 105s - loss: 0.8617 - acc: 0.6550 - val_loss: 0.8123 - val_acc: 0.6596
# Epoch 9/10
#  - 105s - loss: 0.8526 - acc: 0.6615 - val_loss: 0.8027 - val_acc: 0.6689
# Epoch 10/10
#  - 104s - loss: 0.8293 - acc: 0.6681 - val_loss: 0.8067 - val_acc: 0.6753

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.6859375
# train_loss: 0.7815649366378784
# validation_acc: 0.665625
# validation_loss: 0.8166543233394623

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model5.h5')

# %% [markdown]
# Model 6 - 32 64 128 256 / 256 Dropout 256 Dropout / 0.0001

# %%
# Model 5
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 15, 15, 256)       295168
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               3211520
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 3,666,756
# Trainable params: 3,666,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 109s - loss: 1.1491 - acc: 0.4845 - val_loss: 0.9228 - val_acc: 0.6159
# Epoch 2/10
#  - 107s - loss: 0.9582 - acc: 0.6040 - val_loss: 0.9237 - val_acc: 0.6144
# Epoch 3/10
#  - 107s - loss: 0.8869 - acc: 0.6446 - val_loss: 0.8273 - val_acc: 0.6621
# Epoch 4/10
#  - 107s - loss: 0.8340 - acc: 0.6677 - val_loss: 0.7863 - val_acc: 0.6801
# Epoch 5/10
#  - 107s - loss: 0.7889 - acc: 0.6881 - val_loss: 0.7782 - val_acc: 0.6803
# Epoch 6/10
#  - 106s - loss: 0.7578 - acc: 0.7020 - val_loss: 0.7577 - val_acc: 0.6965
# Epoch 7/10
#  - 109s - loss: 0.7270 - acc: 0.7133 - val_loss: 0.7918 - val_acc: 0.6771
# Epoch 8/10
#  - 109s - loss: 0.7015 - acc: 0.7235 - val_loss: 0.7007 - val_acc: 0.7206
# Epoch 9/10
#  - 109s - loss: 0.6757 - acc: 0.7394 - val_loss: 0.7556 - val_acc: 0.7030
# Epoch 10/10
#  - 109s - loss: 0.6641 - acc: 0.7452 - val_loss: 0.7638 - val_acc: 0.6871

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.745625
# train_loss: 0.6647679734230042
# validation_acc: 0.6875
# validation_loss: 0.7503513872623444

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model6.h5')

# %% [markdown]
# Model 7 - 32 64 128 256 / 256 Dropout 256 Dropout / 0.0001 20 epoch

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=20,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/20
#  - 110s - loss: 0.6485 - acc: 0.7503 - val_loss: 0.7920 - val_acc: 0.6937
# Epoch 2/20
#  - 108s - loss: 0.6321 - acc: 0.7566 - val_loss: 0.6938 - val_acc: 0.7321
# Epoch 3/20
#  - 108s - loss: 0.6131 - acc: 0.7630 - val_loss: 0.6807 - val_acc: 0.7358
# Epoch 4/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-42908e275dae> in <module>()
#      29       validation_data=validation_generator,
#      30       validation_steps=250,  # 8000 images = batch_size * steps
# ---> 31       verbose=2)
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in get(self)
#     601                 try:
#     602                     future = self.queue.get(block=True)
# --> 603                     inputs = future.get(timeout=30)
#     604                     self.queue.task_done()
#     605                 except mp.TimeoutError:
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model7.h5')

# %% [markdown]
# Model 8 - 16 32 64 128 / 256 Dropout 256 Dropout / 0.0001

# %%
# Model 8
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               1605888
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 1,770,148
# Trainable params: 1,770,148
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 107s - loss: 1.1550 - acc: 0.4825 - val_loss: 0.9557 - val_acc: 0.5948
# Epoch 2/10
#  - 106s - loss: 0.9667 - acc: 0.5978 - val_loss: 0.8936 - val_acc: 0.6261
# Epoch 3/10
#  - 106s - loss: 0.8983 - acc: 0.6325 - val_loss: 0.8304 - val_acc: 0.6570
# Epoch 4/10
#  - 105s - loss: 0.8572 - acc: 0.6536 - val_loss: 0.8388 - val_acc: 0.6486
# Epoch 5/10
#  - 106s - loss: 0.8177 - acc: 0.6743 - val_loss: 0.8169 - val_acc: 0.6655
# Epoch 6/10
#  - 105s - loss: 0.7858 - acc: 0.6858 - val_loss: 0.7820 - val_acc: 0.6804
# Epoch 7/10
#  - 105s - loss: 0.7616 - acc: 0.6991 - val_loss: 0.7526 - val_acc: 0.6924
# Epoch 8/10
#  - 106s - loss: 0.7357 - acc: 0.7096 - val_loss: 0.7540 - val_acc: 0.6881
# Epoch 9/10
#  - 106s - loss: 0.7124 - acc: 0.7216 - val_loss: 0.8322 - val_acc: 0.6703
# Epoch 10/10
#  - 106s - loss: 0.6957 - acc: 0.7295 - val_loss: 0.7161 - val_acc: 0.7106

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.763125
# train_loss: 0.6073684871196747
# validation_acc: 0.72
# validation_loss: 0.7010717612504959

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model8.h5')

# %% [markdown]
# Model 9 - 32 64 128 256 / 512 Dropout 512 Dropout / 0.0001

# %%
# Model 9
from keras import layers
from keras import models

model = models. Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(4, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 15, 15, 256)       295168
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               6423040
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 7,076,164
# Trainable params: 7,076,164
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=10,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/10
#  - 110s - loss: 1.1235 - acc: 0.5034 - val_loss: 0.9572 - val_acc: 0.5917
# Epoch 2/10
#  - 107s - loss: 0.9310 - acc: 0.6198 - val_loss: 0.9109 - val_acc: 0.6251
# Epoch 3/10
#  - 108s - loss: 0.8584 - acc: 0.6512 - val_loss: 0.8344 - val_acc: 0.6552
# Epoch 4/10
#  - 108s - loss: 0.8004 - acc: 0.6757 - val_loss: 0.7800 - val_acc: 0.6867
# Epoch 5/10
#  - 108s - loss: 0.7557 - acc: 0.6989 - val_loss: 0.7750 - val_acc: 0.6827
# Epoch 6/10
#  - 108s - loss: 0.7184 - acc: 0.7125 - val_loss: 0.7953 - val_acc: 0.6960
# Epoch 7/10
#  - 108s - loss: 0.6851 - acc: 0.7318 - val_loss: 0.7151 - val_acc: 0.7199
# Epoch 8/10
#  - 108s - loss: 0.6502 - acc: 0.7464 - val_loss: 0.7155 - val_acc: 0.7155
# Epoch 9/10
#  - 108s - loss: 0.6245 - acc: 0.7564 - val_loss: 0.7151 - val_acc: 0.7165
# Epoch 10/10
#  - 109s - loss: 0.5961 - acc: 0.7688 - val_loss: 0.7383 - val_acc: 0.7055

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.794375
# train_loss: 0.5401243525743484
# validation_acc: 0.71
# validation_loss: 0.7275440281629563

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model9.h5')

# %% [markdown]
# Model 10 - 32 64 128 256 / 512 Dropout 512 Dropout / 0.0001 / 7 epoch

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers 

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(150, 150),  
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

model.compile(loss='categorical_crossentropy',
              optimizer= optimizers.RMSprop(lr=0.0001),
              metrics=['acc'])

model_history = model.fit_generator(
      train_generator,
      steps_per_epoch=750,  # 24000 images = batch_size * steps
      epochs=7,
      validation_data=validation_generator,
      validation_steps=250,  # 8000 images = batch_size * steps
      verbose=2)
# Out:
# Found 24000 images belonging to 4 classes.
# Found 8000 images belonging to 4 classes.
# Epoch 1/7
#  - 111s - loss: 0.5795 - acc: 0.7780 - val_loss: 0.7581 - val_acc: 0.6956
# Epoch 2/7
#  - 109s - loss: 0.5495 - acc: 0.7894 - val_loss: 0.7099 - val_acc: 0.7296
# Epoch 3/7
#  - 107s - loss: 0.5383 - acc: 0.7968 - val_loss: 0.7468 - val_acc: 0.7340
# Epoch 4/7
#  - 108s - loss: 0.5092 - acc: 0.8069 - val_loss: 0.7374 - val_acc: 0.7274
# Epoch 5/7
#  - 107s - loss: 0.4929 - acc: 0.8145 - val_loss: 0.7183 - val_acc: 0.7285
# Epoch 6/7
#  - 107s - loss: 0.4748 - acc: 0.8212 - val_loss: 0.7851 - val_acc: 0.7304
# Epoch 7/7
#  - 107s - loss: 0.4624 - acc: 0.8278 - val_loss: 0.7135 - val_acc: 0.7389

# %%
train_loss, train_acc = model.evaluate_generator(train_generator, steps=50)
print('train_acc:', train_acc)
print('train_loss:', train_loss)

validation_loss, validation_acc = model.evaluate_generator(validation_generator, steps=50)
print('validation_acc:', validation_acc)
print('validation_loss:', validation_loss)

import matplotlib.pyplot as plt

acc = model_history.history['acc']
val_acc = model_history.history['val_acc']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

# Plot training and validation loss per epoch
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# train_acc: 0.885
# train_loss: 0.3313864602148533
# validation_acc: 0.73375
# validation_loss: 0.7216362977027893

# %%
model.save('/content/drive/My Drive/Multi-Class Weather/models/model10.h5')

# %%
from keras.models import load_model
model = load_model("/content/drive/My Drive/Multi-Class Weather/models/model9.h5")
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 15, 15, 256)       295168
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               6423040
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 7,076,164
# Trainable params: 7,076,164
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(150, 150),
        batch_size=32,
        classes = ['cloudy', 'rainy', 'sunny', 'snowy'],
        class_mode='categorical')

test_loss, test_acc = model.evaluate_generator(test_generator, steps=50)
print('test_acc:', test_acc)
# Out:
# Found 8000 images belonging to 4 classes.
# test_acc: 0.666875
